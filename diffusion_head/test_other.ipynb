# %%
agent_trajs = [] # N x T x 2
for i in range(len(trajs_gen)):
    for j in range(1, 7):
        print(trajs_gen[i]['fut_boxes'][j][:,:,:2].shape)
        agent_trajs.append(trajs_gen[i]['fut_boxes'][j][:,:,:2])
    print(len(agent_trajs))
    #trajs_gen[i]['fut_boxes']

# %%
import torch
import matplotlib.pyplot as plt

# 假设轨迹数据的形状为 [32, 6, 2]，其中32表示32条轨迹，6表示每条轨迹有6个点，2表示(x, y)坐标
trajectory_data = trajs_gen[0] # 随机生成数据

# 创建一个新的图形
plt.figure()

# 遍历每条轨迹
for i in range(trajectory_data.shape[0]):
    trajectory = trajectory_data[i]  # 取出第i条轨迹
    x = trajectory[:, 0].cpu()  # x坐标
    y = trajectory[:, 1].cpu()  # y坐标
    plt.plot(x, y)  # 用线连接每个轨迹的点，并标出点的位置

# 添加标题和坐标轴标签
plt.title('128 Trajectories')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 显示图形
plt.show()

# %%
import torch
import matplotlib.pyplot as plt

# 假设轨迹数据的形状为 [32, 6, 2]，其中32表示32条轨迹，6表示每条轨迹有6个点，2表示(x, y)坐标
trajectory_data = trajs_gen[0] # 随机生成数据

# 创建一个新的图形
plt.figure()

# 遍历每条轨迹
for i in range(trajectory_data.shape[0]):
    trajectory = trajectory_data[i]  # 取出第i条轨迹
    x = trajectory[:, 0].cpu()  # x坐标
    y = trajectory[:, 1].cpu()  # y坐标
    plt.plot(x, y)  # 用线连接每个轨迹的点，并标出点的位置

# 添加标题和坐标轴标签
plt.title('128 Trajectories')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 显示图形
plt.show()

# %%
i = 0
for mask in gt_trajs_mask:
    if not mask.all():
        continue
    else:
        i = i + 1
