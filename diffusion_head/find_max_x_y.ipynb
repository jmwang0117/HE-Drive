# %%
import pickle
filename = "/home/users/xingyu.zhang/workspace/SD-origin/scripts/features_train_all_de_with_anchor.pkl"
trajs_gt = pickle.load(open(filename, 'rb'))

# %%
max = 0
for i in range(len(trajs_gt)):
    value = torch.max(trajs_gt[i]['ego_trajs'][:,:,0][0])
    if value > max:
        max = value
print(max)
# Out:
# tensor(13.9652)

# %%
import torch
torch.max(trajs_gt[0]['ego_trajs'][:,:,1][0])
# Out:
# tensor(29.4489)
